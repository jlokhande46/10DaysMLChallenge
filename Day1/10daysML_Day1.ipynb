# %%
cd drive
# Out:
# [Errno 2] No such file or directory: 'drive'
# /content/drive/My Drive/10daysML_data

# %%
cd My\ Drive
# Out:
# [Errno 2] No such file or directory: 'My Drive'
# /content/drive/My Drive/10daysML_data

# %%
cd 10daysML_data/
# Out:
# [Errno 2] No such file or directory: '10daysML_data/'
# /content/drive/My Drive/10daysML_data

# %%
# Out:
# time_series_2019-ncov-Confirmed.csv

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df=pd.read_csv("time_series_2019-ncov-Confirmed.csv")
df
# Out:
#     Province/State Country/Region      Lat  ...  3/20/20  3/21/20  3/22/20
# 0              NaN       Thailand  15.0000  ...      322      411      599
# 1              NaN          Japan  36.0000  ...      963     1007     1086
# 2              NaN      Singapore   1.2833  ...      385      432      455
# 3              NaN          Nepal  28.1667  ...        1        1        2
# 4              NaN       Malaysia   2.5000  ...     1030     1183     1306
# ..             ...            ...      ...  ...      ...      ...      ...
# 482            NaN       Dominica  15.4150  ...        0        0        1
# 483            NaN        Grenada  12.1165  ...        0        0        1
# 484            NaN     Mozambique -18.6657  ...        0        0        1
# 485            NaN          Syria  34.8021  ...        0        0        1
# 486            NaN    Timor-Leste  -8.8742  ...        0        0        1
#
# [487 rows x 65 columns]

# %%
df=df.drop(columns=['Province/State'])
# Out:
#     Country/Region      Lat      Long  ...  3/20/20  3/21/20  3/22/20
# 0         Thailand  15.0000  101.0000  ...      322      411      599
# 1            Japan  36.0000  138.0000  ...      963     1007     1086
# 2        Singapore   1.2833  103.8333  ...      385      432      455
# 3            Nepal  28.1667   84.2500  ...        1        1        2
# 4         Malaysia   2.5000  112.5000  ...     1030     1183     1306
# ..             ...      ...       ...  ...      ...      ...      ...
# 482       Dominica  15.4150  -61.3710  ...        0        0        1
# 483        Grenada  12.1165  -61.6790  ...        0        0        1
# 484     Mozambique -18.6657   35.5296  ...        0        0        1
# 485          Syria  34.8021   38.9968  ...        0        0        1
# 486    Timor-Leste  -8.8742  125.7275  ...        0        0        1
#
# [487 rows x 64 columns]

# %%
for (columnName, columnData) in df[3:].iteritems():
  c=0
  for i,j in columnData.iteritems():
    c+=1
  if(c<=0.7*486):
    df=df.drop(columns=[columnName])
df
# Out:
#     Country/Region      Lat      Long  ...  3/20/20  3/21/20  3/22/20
# 0         Thailand  15.0000  101.0000  ...      322      411      599
# 1            Japan  36.0000  138.0000  ...      963     1007     1086
# 2        Singapore   1.2833  103.8333  ...      385      432      455
# 3            Nepal  28.1667   84.2500  ...        1        1        2
# 4         Malaysia   2.5000  112.5000  ...     1030     1183     1306
# ..             ...      ...       ...  ...      ...      ...      ...
# 482       Dominica  15.4150  -61.3710  ...        0        0        1
# 483        Grenada  12.1165  -61.6790  ...        0        0        1
# 484     Mozambique -18.6657   35.5296  ...        0        0        1
# 485          Syria  34.8021   38.9968  ...        0        0        1
# 486    Timor-Leste  -8.8742  125.7275  ...        0        0        1
#
# [487 rows x 64 columns]

# %%
plt.figure(figsize=(14,6))
df1=df.nlargest(10, ['3/22/20'])
x = df1.iloc[0:10]['Country/Region']
y = df1.iloc[0:10]['3/22/20']
plt.bar(x, y)
plt.xlabel("Countries")
plt.ylabel("No of cases")
plt.title("Top ten countries with most cases")
plt.show()

# %%
plt.figure(figsize=(30,6))
dates = [date for date in df1[df1.columns[3:]]]
x = dates 
y = df1.iloc[0][3:]
plt.title("Number of cases per day for country China", fontsize=16)
plt.xlabel('Dates')
plt.ylabel('No of cases')
plt.xticks(rotation=45)
plt.plot(x, y)
plt.show()

# %%
continents = pd.read_csv("continent.csv")

# %%
continent_df = pd.merge(left=df, right=continents, left_on='Country/Region', right_on='Country')

# %%
plt.figure(figsize=(12,6))
y=continent_df.groupby('Continent').count()['3/22/20']
x=continent_df['Continent'].unique()
plt.bar(x,y)
plt.title("Total Number of cases on 3/22/20 percontinent")
plt.xlabel("Continents")
plt.ylabel("total number of cases")
# Out:
# Text(0, 0.5, 'total number of cases')
